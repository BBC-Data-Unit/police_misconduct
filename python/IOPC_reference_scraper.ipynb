# %% [markdown]
# # Scraping IOPC reference codes
#
# This scraper builds on a previous notebook which scrapes IOPC reports. In that scraper we didn't grab the IOPC reference codes, so in this notebook we import the resulting CSV and go back through the URLs to grab those.
#
# First, import the libraries we will need.

# %%
#install the libraries
#scraperwiki is a library for scraping webpages
# !pip install scraperwiki
import scraperwiki
#We can also use requests instead
import requests
#lxml.html is used to convert it into xml (more structured)
import lxml.html
#cssselect is used to drill down into that and find data in tags
# !pip install cssselect
import cssselect
#the pandas library which is used to work with data - we call it 'pd' here so we have to type less!
import pandas as pd

# %%
#Just in case we get an IOPub Error
#https://stackoverflow.com/questions/48906481/iopub-error-on-google-colaboratory-in-jupyter-notebook
from pprint import pprint

# %% [markdown]
# ## Import CSV
#
# Now we import the CSV exported from the previous scraper.

# %%
recs = pd.read_csv("recs30june_wforces.csv")
#Show the url column
recs['url']
# Out:
# 0       https://policeconduct.gov.uk/recommendations/r...
# 1       https://policeconduct.gov.uk/recommendations/w...
# 2       https://policeconduct.gov.uk/recommendations/n...
# 3       https://policeconduct.gov.uk/recommendations/i...
# 4       https://policeconduct.gov.uk/recommendations/p...
#                               ...
# 1315    https://policeconduct.gov.uk/recommendations/r...
# 1316    https://policeconduct.gov.uk/recommendations/%...
# 1317    https://policeconduct.gov.uk/recommendations/c...
# 1318    https://policeconduct.gov.uk/recommendations/a...
# 1319    https://policeconduct.gov.uk/recommendations/a...
# Name: url, Length: 1320, dtype: object

# %% [markdown]
# ## Create scraper function for IOPC ref code
#
# The reference code is not easy to grab. It's inside a chunk of HTML like this:
#
# ```{html}
#   <div class="field-label">IOPC reference</div>
#             2019/118999
#   <div class="field-label">Date of recommendation</div>
# ```
#
# So it's not inside its own HTML tag. In fact it's inside the `<div class="clearfix">` that contains the whole recommendation.
#
# The best way to grab it, then, might be regex. For that we will need the regex library `re`.

# %%
import re

# %% [markdown]
# ## Compiling a regular expression
#
# Next we need to [*compile* the regular expression](https://docs.python.org/3/howto/regex.html).

# %%
#compile the regex
p = re.compile("IOPC reference</div>\n\s+[0-9]{4}/[0-9]{6}")
#create some text to test it on
testtext = '''<div class="field-label">IOPC reference</div>
            2019/118999
  <div class="field-label">Date of recommendation</div>'''
#print it
print(testtext)
#test it
print(p.search(testtext))
#store it
matchtext = p.search(testtext)
#extract the match
print(matchtext[0])
#clean the match
print(matchtext[0].split('\n')[1].strip())
# Out:
# <div class="field-label">IOPC reference</div>
#             2019/118999
#   <div class="field-label">Date of recommendation</div>
# <re.Match object; span=(25, 69), match='IOPC reference</div>\n            2019/118999'>
# IOPC reference</div>
#             2019/118999
# 2019/118999

# %% [markdown]
# ## Test on some pages
#
# Now let's test that on one page. To do that we will need to scrape it, too.

# %%
#scrape the 3rd URL in that column
html = scraperwiki.scrape(recs['url'][2])
#print - it's a byte object (contained within b'')...
print(html)
#so will need to be decoded first
#see https://stackoverflow.com/questions/606191/convert-bytes-to-a-string
html = html.decode("utf-8")
#...before regex can be used
print(p.search(html)[0].split('\n')[1].strip())
# Out:
# b'<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML+RDFa 1.0//EN" "http://www.w3.org/MarkUp/DTD/xhtml-rdfa-1.dtd">\n<html lang="en" xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" version="XHTML+RDFa 1.0"\n      dir="ltr"\n  xmlns:content="http://purl.org/rss/1.0/modules/content/"\n  xmlns:dc="http://purl.org/dc/terms/"\n  xmlns:foaf="http://xmlns.com/foaf/0.1/"\n  xmlns:og="http://ogp.me/ns#"\n  xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"\n  xmlns:sioc="http://rdfs.org/sioc/ns#"\n  xmlns:sioct="http://rdfs.org/sioc/types#"\n  xmlns:skos="http://www.w3.org/2004/02/skos/core#"\n  xmlns:xsd="http://www.w3.org/2001/XMLSchema#"\n  xmlns:schema="http://schema.org/">\n<head profile="http://www.w3.org/1999/xhtml/vocab">\n  <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<meta name="Generator" content="Drupal 7 (http://drupal.org)" />\n<link rel="canonical" href="/recommendations/national-recommendation-college-policing-june-2021" />\n<link rel="shortlink" href="/node/29728" />\n<link rel="shortcut icon" href="https://policeconduct.gov.uk/sites/all/themes/iopc/favicon.ico" type="image/png" />\n<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=5, minimum-scale=1, user-scalable=yes" />\n    <title>National recommendation - The College of Policing, June 2021 | Independent Office for Police Conduct</title>\n    \n<script id="Cookiebot" src="https://consent.cookiebot.com/uc.js" data-cbid="964bf3ac-3bb8-4d5e-ad17-a233ba19364f" data-blockingmode="auto" type="text/javascript"></script>\n    <link href=\'//fonts.googleapis.com/css?family=Open+Sans:400,700,400italic,700italic\' rel=\'stylesheet\'\n          type=\'text/css\'>\n    <!--[if lte IE 8]>\n    <link rel="stylesheet" href="http://fonts.googleapis.com/css?family=Open+Sans:400"/>\n    <link rel="stylesheet" href="http://fonts.googleapis.com/css?family=Open+Sans:400italic"/>\n    <link rel="stylesheet" href="http://fonts.googleapis.com/css?family=Open+Sans:700"/>\n    <link rel="stylesheet" href="http://fonts.googleapis.com/css?family=Open+Sans:700italic"/>\n    <![endif]-->\n    <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>\n  \n<!--[if (lt IE 9)&(!IEMobile)]>\n<style type="text/css" media="all">\n<!--/*--><![CDATA[/*><!--*/\n.alpha-grid-debug .container-12{background-image:url(https://policeconduct.gov.uk/sites/all/themes/omega/alpha/css/grid/alpha_default/normal/alpha-default-normal-12.png);}\n.alpha-grid-debug .container-24{background-image:url(https://policeconduct.gov.uk/sites/all/themes/omega/alpha/css/grid/alpha_default/normal/alpha-default-normal-24.png);}\n\n/*]]>*/-->\n</style>\n<![endif]-->\n\n<!--[if gte IE 9]><!-->\n<style type="text/css" media="all and (min-width: 740px) and (min-device-width: 740px), (max-device-width: 800px) and (min-width: 740px) and (orientation:landscape)">\n<!--/*--><![CDATA[/*><!--*/\n.alpha-grid-debug .container-12{background-image:url(https://policeconduct.gov.uk/sites/all/themes/omega/alpha/css/grid/alpha_default/narrow/alpha-default-narrow-12.png);}\n.alpha-grid-debug .container-24{background-image:url(https://policeconduct.gov.uk/sites/all/themes/omega/alpha/css/grid/alpha_default/narrow/alpha-default-narrow-24.png);}\n\n/*]]>*/-->\n</style>\n<!--<![endif]-->\n\n<!--[if gte IE 9]><!-->\n<style type="text/css" media="all and (min-width: 980px) and (min-device-width: 980px), all and (max-device-width: 1024px) and (min-width: 1024px) and (orientation:landscape)">\n<!--/*--><![CDATA[/*><!--*/\n.alpha-grid-debug .container-12{background-image:url(https://policeconduct.gov.uk/sites/all/themes/omega/alpha/css/grid/alpha_default/normal/alpha-default-normal-12.png);}\n.alpha-grid-debug .container-24{background-image:url(https://policeconduct.gov.uk/sites/all/themes/omega/alpha/css/grid/alpha_default/normal/alpha-default-normal-24.png);}\n\n/*]]>*/-->\n</style>\n<!--<![endif]-->\n\n<!--[if gte IE 9]><!-->\n<style type="text/css" media="all and (min-width: 1220px)">\n<!--/*--><![CDA ...
# 2020/137342

# %% [markdown]
# Some URLs won't have a ref. What happens then?

# %%
for i in recs['url'][:10]:
  print(i)
  #scrape the 2nd URL in that column
  html = scraperwiki.scrape(i)
  #so will need to be decoded first
  #see https://stackoverflow.com/questions/606191/convert-bytes-to-a-string
  html = html.decode("utf-8")
  #...before regex can be used
  print(p.search(html)[0].split('\n')[1].strip())
# Out:
# https://policeconduct.gov.uk/recommendations/recommendations-sussex-police-april-2021
# 2020/135656
# https://policeconduct.gov.uk/recommendations/woman-was-found-dead-after-welfare-concerns-reported-thames-valley-police-april-2020
# 2020/135205
# https://policeconduct.gov.uk/recommendations/national-recommendation-college-policing-june-2021
# 2020/137342
# https://policeconduct.gov.uk/recommendations/inappropriate-communications-member-public-%E2%80%93-cambridgeshire-police-and-crime-panel
# 2019/127658
# https://policeconduct.gov.uk/recommendations/police-management-registered-terrorist-offender-following-his-release-prison-%E2%80%93
# 2019/128766
# https://policeconduct.gov.uk/recommendations/fatal-police-shooting-terrorist-attacker-%E2%80%93-city-london-police-and-metropolitan
# 2019/128689
# https://policeconduct.gov.uk/recommendations/death-following-police-pursuit-%E2%80%93-hampshire-constabulary-august-2020
# 2020/140719
# https://policeconduct.gov.uk/recommendations/death-following-police-investigation-sexual-offence-south-yorkshire-police-october
# 2019/117002
# https://policeconduct.gov.uk/recommendations/use-taser-%E2%80%93-metropolitan-police-service-march-2019
# 2019/116931
# https://policeconduct.gov.uk/recommendations/recommendation-essex-police-march-2021
# 2019/128944

# %% [markdown]
# We couldn't check that way, so let's try another approach.

# %%
#compile the regex
p = re.compile("IOPC reference</div>\n\s+[0-9]{4}/[0-9]{6}")
#create some text to test it on
testtext = '''<div class="field-label">IOPC reference</div>
  <div class="field-label">Date of recommendation</div>'''
#print it
pprint(testtext)
#test it
print(p.search(testtext))
#store it
matchtext = p.search(testtext)
#check how many matches - matchtext is True/False
if matchtext:
  print("match")
else:
  print("No matches")
#extract the match
print(matchtext[0])
#clean the match
print(matchtext[0].split('\n')[1].strip())
# Out:
# ('<div class="field-label">IOPC reference</div>\n'
#  '  <div class="field-label">Date of recommendation</div>')
# None
# No matches
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-a1f08bf97fe1> in <module>()
#      16   print("No matches")
#      17 #extract the match
# ---> 18 print(matchtext[0])
#      19 #clean the match
#      20 print(matchtext[0].split('\n')[1].strip())
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# ## Create a function
#
# With testing done, let's create a function that we can run on each URL to extract the IOPC ref if it's there, or an alternative if not. This needs to be stored alongside the URL for matching against the full record later.

# %%
#define a new function called getref, which takes 1 argument - a URL string
def getref(url):
  #scrape the webpage at that URL
  html = scraperwiki.scrape(url)
  #it will need to be decoded ...
  #see https://stackoverflow.com/questions/606191/convert-bytes-to-a-string
  html = html.decode("utf-8")
  #compile the regex
  refregex = re.compile("IOPC reference</div>\n\s+[0-9]{4}/[0-9]{6}")
  #grab any matches of that
  regexmatches = refregex.search(html)
  #check if there is a match
  if regexmatches:
    #print ref code
    iopcref = refregex.search(html)[0].split('\n')[1].strip()
  else:
    iopcref = "no ref found"
  return(iopcref)

# %% [markdown]
# A quick test:

# %%
testref = getref(recs['url'][0])
print(testref)
# Out:
# 2020/135656

# %% [markdown]
# ## Run the function on multiple URLs
#
# With that done, we can run it on a list of URLs.

# %%
#create an empty list to add to
runninglist = []
#loop through urls
for i in recs['url'][:10]:
  print(i)
  #run function to grab ref from that page
  grabbedref = getref(i)
  #add to a dict along with the URL for matching
  runningdict = {'url':i, 'iopcref':grabbedref}
  #add to a list, too, which may be easier
  runninglist.append(grabbedref+i)
  print(runningdict)
  print(runninglist)
# Out:
# https://policeconduct.gov.uk/recommendations/recommendations-sussex-police-april-2021
# {'url': 'https://policeconduct.gov.uk/recommendations/recommendations-sussex-police-april-2021', 'iopcref': '2020/135656'}
# ['2020/135656https://policeconduct.gov.uk/recommendations/recommendations-sussex-police-april-2021']
# https://policeconduct.gov.uk/recommendations/woman-was-found-dead-after-welfare-concerns-reported-thames-valley-police-april-2020
# {'url': 'https://policeconduct.gov.uk/recommendations/woman-was-found-dead-after-welfare-concerns-reported-thames-valley-police-april-2020', 'iopcref': '2020/135205'}
# ['2020/135656https://policeconduct.gov.uk/recommendations/recommendations-sussex-police-april-2021', '2020/135205https://policeconduct.gov.uk/recommendations/woman-was-found-dead-after-welfare-concerns-reported-thames-valley-police-april-2020']
# https://policeconduct.gov.uk/recommendations/national-recommendation-college-policing-june-2021
# {'url': 'https://policeconduct.gov.uk/recommendations/national-recommendation-college-policing-june-2021', 'iopcref': '2020/137342'}
# ['2020/135656https://policeconduct.gov.uk/recommendations/recommendations-sussex-police-april-2021', '2020/135205https://policeconduct.gov.uk/recommendations/woman-was-found-dead-after-welfare-concerns-reported-thames-valley-police-april-2020', '2020/137342https://policeconduct.gov.uk/recommendations/national-recommendation-college-policing-june-2021']
# https://policeconduct.gov.uk/recommendations/inappropriate-communications-member-public-%E2%80%93-cambridgeshire-police-and-crime-panel
# {'url': 'https://policeconduct.gov.uk/recommendations/inappropriate-communications-member-public-%E2%80%93-cambridgeshire-police-and-crime-panel', 'iopcref': '2019/127658'}
# ['2020/135656https://policeconduct.gov.uk/recommendations/recommendations-sussex-police-april-2021', '2020/135205https://policeconduct.gov.uk/recommendations/woman-was-found-dead-after-welfare-concerns-reported-thames-valley-police-april-2020', '2020/137342https://policeconduct.gov.uk/recommendations/national-recommendation-college-policing-june-2021', '2019/127658https://policeconduct.gov.uk/recommendations/inappropriate-communications-member-public-%E2%80%93-cambridgeshire-police-and-crime-panel']
# https://policeconduct.gov.uk/recommendations/police-management-registered-terrorist-offender-following-his-release-prison-%E2%80%93
# {'url': 'https://policeconduct.gov.uk/recommendations/police-management-registered-terrorist-offender-following-his-release-prison-%E2%80%93', 'iopcref': '2019/128766'}
# ['2020/135656https://policeconduct.gov.uk/recommendations/recommendations-sussex-police-april-2021', '2020/135205https://policeconduct.gov.uk/recommendations/woman-was-found-dead-after-welfare-concerns-reported-thames-valley-police-april-2020', '2020/137342https://policeconduct.gov.uk/recommendations/national-recommendation-college-policing-june-2021', '2019/127658https://policeconduct.gov.uk/recommendations/inappropriate-communications-member-public-%E2%80%93-cambridgeshire-police-and-crime-panel', '2019/128766https://policeconduct.gov.uk/recommendations/police-management-registered-terrorist-offender-following-his-release-prison-%E2%80%93']
# https://policeconduct.gov.uk/recommendations/fatal-police-shooting-terrorist-attacker-%E2%80%93-city-london-police-and-metropolitan
# {'url': 'https://policeconduct.gov.uk/recommendations/fatal-police-shooting-terrorist-attacker-%E2%80%93-city-london-police-and-metropolitan', 'iopcref': '2019/128689'}
# ['2020/135656https://policeconduct.gov.uk/recommendations/recommendations-sussex-police-april-2021', '2020/135205https://policeconduct.gov.uk/recommendations/woman-was-found-dead-after-welfare-concerns-reported-thames-valley-police-april-2020', '2020/137342https://policeconduct.gov.uk/recommendations/national-recommendation-college-policing-june-2021', '2019/127658https://policeconduct.gov.uk/recommendations/inappropriate-communications-member-public-%E2%80%93-cambridgeshire-police-and-crime-panel', '2019/128766https://policeconduct.gov.uk/recommendations/police-management-registered-terrorist-offender-following-his-release-prison-%E2%80%93', '2019/128689https://policeconduct.gov.uk/recommendations/fatal-police-shooting-terrorist-attacker-%E2%80%93-city-london-police-and-metropolitan']
# https://policeconduct.gov.uk/recommendations/death-following-police-pursuit-%E2%80%93-hampshire-constabulary-august-2020
# {'url': 'https://policeconduct.gov.uk/recommendations/death-following-police-pursuit-%E2%80%93-hampshire-constabulary-august-2020', 'iopcref': '2020/140719'}
# ['2020/135656https://policeconduct.gov.uk/recommendations/recommendations-sussex-police-april-2021', '2020/135205https://policeconduct.gov.uk/recommendations/woman-was-found-dead-after-welfare-concerns-reported-thames-valley-police-april-2020', '2020/137342https://policeconduct.gov.uk/recommendations/national-recommendation-college-policing-june-2021', '2019/127658https://policeconduct.gov.uk/recommendations/inappropriate-communications-member-public-%E2%80%93-cambridgeshire-police-and-crime-panel', '2019/128766https://policeconduct.gov.uk/recommendations/police-management-registered-terrorist-offender-following-his-release-prison-%E2%80%93', '2019/128689https://policeconduct.gov.uk/recommendations/fatal-police-shooting-terrorist-attacker-%E2%80%93-city-london-police-and-metropolitan', '2020/140719https://policeconduct.gov.uk/recommendations/death-following-police-pursuit-%E2%80%93-hampshire-constabulary-august-2020']
# https://policeconduct.gov.uk/recommendations/death-following-police-investigation-sexual-offence-south-yorkshire-police-october
# {'url': 'https://policeconduct.gov.uk/recommendations/death-following-police-investigation-sexual-offence-south-yorkshire-police-october', 'iopcref': '2019/117002'}
# ['2020/135656https://policeconduct.gov.uk/recommendations/recommendations-sussex-police-april-2021', '2020/135205https://policeconduct.gov.uk/recommendations/woman-was-found-dead-after-welfare-concerns-reported-thames-valley-police-april-2020', '2020/137342https://policeconduct.gov.uk/recommendations/national-recommendation-college-policing-june-2021', '2019/127658https://policeconduct.gov.uk/recommendations/inappropriate-communications-member-public-%E2%80%93-cambridgeshire-police-and-crime-panel', '2019/128766https://policeconduct.gov.uk/recommendations/police-management-registered-terrorist-offender-following-his-release-prison-%E2%80%93', '2019/128689https://policeconduct.gov.uk/recommendations/fatal-police-shooting-terrorist-attacker-%E2%80%93-city-london-police-and-metropolitan', '2020/140719https://policeconduct.gov.uk/recommendations/death-following-police-pursuit-%E2%80%93-hampshire-constabulary-august-2020', '2019/117002https://policeconduct.gov.uk/recommendations/death-following-police-investigation-sexual-offence-south-yorkshire-police-october']
# https://policeconduct.gov.uk/recommendations/use-taser-%E2%80%93-metropolitan-police-service-march-2019
# {'url': 'https://policeconduct.gov.uk/recommendations/use-taser-%E2%80%93-metropolitan-police-service-march-2019', 'iopcref': '2019/116931'}
# ['2020/135656https://policeconduct.gov.uk/recommendations/recommendations-sussex-police-april-2021', '2020/135205https://policeconduct.gov.uk/recommendations/woman-was-found-dead-after-welfare-concerns-reported-thames-valley-police-april-2020', '2020/137342https://policeconduct.gov.uk/recommendations/national-recommendation-college-policing-june-2021', '2019/127658https://policeconduct.gov.uk/recommendations/inappropriate-communications-member-public-%E2%80%93-cambridgeshire-police-and-crime-panel', '2019/128766https://policeconduct.gov.uk/recommendations/police-management-registered-terrorist-offender-following-his-release-prison-%E2%80%93', '2019/128689https://policeconduct.gov.uk/recommendations/fatal-police-shooting-terrorist-attacker-%E2%80%93-city-london-police-and-metropolitan', '2020/140719https://policeconduct.gov.uk/recommendations/death-following-police-pursuit-%E2%80%93-hampshire-constabulary-august-2020', '2019/117002https://policeconduct.gov.uk/recommendations/death-following-police-investigation-sexual-offence-south-yorkshire-police-october', '2019/116931https://policeconduct.gov.uk/recommendations/use-taser-%E2%80%93-metropolitan-police-service-march-2019']
# https://policeconduct.gov.uk/recommendations/recommendation-essex-police-march-2021
# {'url': 'https://policeconduct.gov.uk/recommendations/recommendation-essex-police-march-2021', 'iopcref': '2019/128944'}
# ['2020/135656https://policeconduct.gov.uk/recommendations/recommendations-sussex-police-april-2021', '2020/135205https://policeconduct.gov.uk/recommendations/woman-was-found-dead-after-welfare-concerns-reported-thames-valley-police-april-2020', '2020/137342https://policeconduct.gov.uk/recommendations/national-recommendation-college-policing-june-2021', '2019/127658https://policeconduct.gov.uk/recommendations/inappropriate-communications-member-public-%E2%80%93-cambridgeshire-police-and-crime-panel', '2019/128766https://policeconduct.gov.uk/recommendations/police-management-registered-terrorist-offender-following-his-release-prison-%E2%80%93', '2019/128689https://policeconduct.gov.uk/recommendations/fatal-police-shooting-terrorist-attacker-%E2%80%93-city-london-police-and-metropolitan', '2020/140719https://policeconduct.gov.uk/recommendations/death-following-police-pursuit-%E2%80%93-hampshire-constabulary-august-2020', '2019/117002https://policeconduct.gov.uk/recommendations/death-following-police-investigation-sexual-offence-south-yorkshire-police-october', '2019/116931https://policeconduct.gov.uk/recommendations/use-taser-%E2%80%93-metropolitan-police-service-march-2019', '2019/128944https://policeconduct.gov.uk/recommendations/recommendation-essex-police-march-2021']

# %% [markdown]
# And the whole lot - this time we also create an empty data frame and add each dict as we go:

# %%
#create an empty list to add to
runninglist = []
#create an empty data frame to add to
df = pd.DataFrame(columns=["url","iopcref"])
#loop through urls
for i in recs['url']:
  print(i)
  #run function to grab ref from that page
  grabbedref = getref(i)
  #add to a dict along with the URL for matching
  runningdict = {'url':i, 'iopcref':grabbedref}
  #add to a list, too, which may be easier
  runninglist.append(grabbedref+i)
  #print(runningdict)
  #print(runninglist)
  #append to our dataframe
  df = df.append(
    runningdict,
    ignore_index=True
    )

# %% [markdown]
# ## Checking gaps
#
# Let's check those URLs where a ref wasn't found.

# %%
#create a dataframe by filtering on those rows where iopcref is 'no ref found'
norefs = df[df['iopcref'] == "no ref found"]
#show the urls in that new dataframe
norefs['url']
# Out:
# 850     https://policeconduct.gov.uk/recommendations/f...
# 852     https://policeconduct.gov.uk/recommendations/p...
# 856     https://policeconduct.gov.uk/recommendations/r...
# 982     https://policeconduct.gov.uk/recommendations/r...
# 983     https://policeconduct.gov.uk/recommendations/r...
#                               ...
# 1089    https://policeconduct.gov.uk/recommendations/r...
# 1090    https://policeconduct.gov.uk/recommendations/r...
# 1091    https://policeconduct.gov.uk/recommendations/r...
# 1092    https://policeconduct.gov.uk/recommendations/r...
# 1197    https://policeconduct.gov.uk/recommendations/r...
# Name: url, Length: 106, dtype: object

# %%
for i in norefs['url'][:5]:
  print(i)
# Out:
# https://policeconduct.gov.uk/recommendations/fatal-collision-derbyshire-constabulary-september-2017
# https://policeconduct.gov.uk/recommendations/pedestrian-killed-collision-police-car-west-midlands-police-april-2012
# https://policeconduct.gov.uk/recommendations/response-report-bad-driving-kent-police-august-2017
# https://policeconduct.gov.uk/recommendations/recommendation-humberside-police-november-2014
# https://policeconduct.gov.uk/recommendations/recommendation-northamptonshire-police-december-2014

# %% [markdown]
# [Looking at one page](https://policeconduct.gov.uk/recommendations/allegations-assault-during-custody-merseyside-police-october-2016) we can see the reference has an extra digit - the year is incorrectly entered as 22017:
#
# ```{html}
# <div class="field-label">IOPC reference</div>
#             22017/082348                        </div>
# ```
#
# On [another](https://policeconduct.gov.uk/recommendations/fatal-collision-derbyshire-constabulary-september-2017) it's a dash instead of a slash:
#
# `2017-091299`
#
# And on [another](https://policeconduct.gov.uk/recommendations/response-report-bad-driving-kent-police-august-2017) there's no slash *or* dash:
#
# `2017090856`
#
# So we need to adjust the regex.

# %%
#define a new function called getref, which takes 1 argument - a URL string
def getref(url):
  #scrape the webpage at that URL
  html = scraperwiki.scrape(url)
  #it will need to be decoded ...
  #see https://stackoverflow.com/questions/606191/convert-bytes-to-a-string
  html = html.decode("utf-8")
  #compile the regex - this will accept 3-5 digits and 4-7 digits in the code
  refregex = re.compile("IOPC reference</div>\n\s+[0-9]{3,5}[/-]?[0-9]{4,7}")
  #grab any matches of that
  regexmatches = refregex.search(html)
  #check if there is a match
  if regexmatches:
    #print ref code
    iopcref = regexmatches[0].split('\n')[1].strip()
  else:
    iopcref = "no ref found"
  return(iopcref)

testurl = "https://policeconduct.gov.uk/recommendations/allegations-assault-during-custody-merseyside-police-october-2016"
print(getref(testurl))
testurl = "https://policeconduct.gov.uk/recommendations/fatal-collision-derbyshire-constabulary-september-2017"
print(getref(testurl))
testurl = "https://policeconduct.gov.uk/recommendations/response-report-bad-driving-kent-police-august-2017"
print(getref(testurl))
# Out:
# 22017/082348
# 2017-091299
# 2017090856

# %% [markdown]
# Then run it again.

# %%
#create an empty list to add to
runninglist = []
#create an empty data frame to add to
df = pd.DataFrame(columns=["url","iopcref"])
#loop through urls
for i in recs['url']:
  print(i)
  #run function to grab ref from that page
  grabbedref = getref(i)
  #add to a dict along with the URL for matching
  runningdict = {'url':i, 'iopcref':grabbedref}
  #add to a list, too, which may be easier
  runninglist.append(grabbedref+i)
  #print(runningdict)
  #print(runninglist)
  #append to our dataframe
  df = df.append(
    runningdict,
    ignore_index=True
    )
# Out:
# https://policeconduct.gov.uk/recommendations/recommendations-sussex-police-april-2021
# https://policeconduct.gov.uk/recommendations/woman-was-found-dead-after-welfare-concerns-reported-thames-valley-police-april-2020
# https://policeconduct.gov.uk/recommendations/national-recommendation-college-policing-june-2021
# https://policeconduct.gov.uk/recommendations/inappropriate-communications-member-public-%E2%80%93-cambridgeshire-police-and-crime-panel
# https://policeconduct.gov.uk/recommendations/police-management-registered-terrorist-offender-following-his-release-prison-%E2%80%93
# https://policeconduct.gov.uk/recommendations/fatal-police-shooting-terrorist-attacker-%E2%80%93-city-london-police-and-metropolitan
# https://policeconduct.gov.uk/recommendations/death-following-police-pursuit-%E2%80%93-hampshire-constabulary-august-2020
# https://policeconduct.gov.uk/recommendations/death-following-police-investigation-sexual-offence-south-yorkshire-police-october
# https://policeconduct.gov.uk/recommendations/use-taser-%E2%80%93-metropolitan-police-service-march-2019
# https://policeconduct.gov.uk/recommendations/recommendation-essex-police-march-2021
# https://policeconduct.gov.uk/recommendations/police-response-abandoned-emergency-call-%E2%80%93-cleveland-police-march-2020
# https://policeconduct.gov.uk/recommendations/death-man-after-failure-stop-police-%E2%80%93-west-yorkshire-police-july-2019
# https://policeconduct.gov.uk/recommendations/recommendations-devon-and-cornwall-constabulary-december-2020
# https://policeconduct.gov.uk/recommendations/death-following-contact-police-north-yorkshire-police-february-2019
# https://policeconduct.gov.uk/recommendations/man-sustained-serious-injury-while-custody-%E2%80%93-cleveland-police-august-2019
# https://policeconduct.gov.uk/recommendations/national-recommendation-national-police-chiefs-council-april-2021
# https://policeconduct.gov.uk/recommendations/recommendations-northumbria-police-march-2021
# https://policeconduct.gov.uk/recommendations/recommendation-sussex-police-february-2021
# https://policeconduct.gov.uk/recommendations/recommendation-sussex-police-april-2021
# https://policeconduct.gov.uk/recommendations/recommendation-norfolk-constabulary-march-2021
# https://policeconduct.gov.uk/recommendations/national-recommendations-national-police-chiefs-council-august-2020
# https://policeconduct.gov.uk/recommendations/recommendations-northamptonshire-police-march-2021
# https://policeconduct.gov.uk/recommendations/recommendations-kent-police-november-2020
# https://policeconduct.gov.uk/recommendations/recommendation-metropolitan-police-february-2021
# https://policeconduct.gov.uk/recommendations/national-recommendation-national-police-chiefs-council-february-2021
# https://policeconduct.gov.uk/recommendations/death-woman-home-west-yorkshire-police-may-2020
# https://policeconduct.gov.uk/recommendations/recommendation-hertfordshire-constabulary-march-2021
# https://policeconduct.gov.uk/recommendations/recommendation-bedfordshire-police-november-2020
# https://policeconduct.gov.uk/recommendations/recommendation-greater-manchester-police-december-2020
# https://policeconduct.gov.uk/recommendations/recommendation-metropolitan-police-october-2020
# https://policeconduct.gov.uk/recommendations/recommendations-nottinghamshire-police-january-2021
# https://policeconduct.gov.uk/recommendations/recommendations-greater-manchester-police-december-2020
# https://policeconduct.gov.uk/recommendations/recommendation-humberside-police-february-2021
# https://policeconduct.gov.uk/recommendations/recommendation-kent-police-february-2021
# https://policeconduct.gov.uk/recommendations/recommendations-suffolk-constabulary-october-2020
# https://policeconduct.gov.uk/recommendations/recommendations-gwent-police-february-2021
# https://policeconduct.gov.uk/recommendations/police-investigation-serious-sexual-offences-%E2%80%93-cambridgeshire-constabulary-july-2019
# https://policeconduct.gov.uk/recommendations/collision-another-car-causing-serious-injury-northumbria-police-march-2020
# https://policeconduct.gov.uk/recommendations/police-response-altercation-metropolitan-police-service-july-2019
# https://policeconduct.gov.uk/recommendations/investigation-nature-contact-between-officer-and-member-public-greater-manchester
# https://policeconduct.gov.uk/recommendations/use-force-detainee-metropolitan-police-service-1-december-2018
# https://policeconduct.gov.uk/recommendations/road-traffic-incident-following-pursuit-west-yorkshire-police-july-2020
# https://policeconduct.gov.uk/recommendations/response-missing-person-report-gwent-police-august-2019
# https://policeconduct.gov.uk/recommendations/response-calls-expressing-concern-woman%E2%80%99s-welfare-leicestershire-police-october-2018
# https://policeconduct.gov.uk/recommendations/inappropriate-relationship-person-encountered-part-policing-role-and-duties-suffolk
# https://policeconduct.gov.uk/recommendations/response-missing-person-report-humberside-police-november-2019
# https://policeconduct.gov.uk/recommendations/content-found-mobile-phone-metropolitan-police-service-january-2018
# https://policeconduct.gov.uk/recommendations/road-traffic-collision-between-marked-police-car-and-pedestrians-devon-and-0
# https://policeconduct.gov.uk/recommendations/death-woman-following-police-contact-%E2%80%93-lincolnshire-police-march-2020
# https://policeconduct.gov.uk/recommendations/recommendations-west-yorkshire-police-february-2021
# https://policeconduct.gov.uk/recommendations/response-calls-about-man%E2%80%99s-behaviour-avon-and-somerset-constabulary-november-2019
# https://policeconduct.gov.uk/recommendations/contact-man-he-jumped-roof-devon-and-cornwall-police-march-2020
# https://policeconduct.gov.uk/recommendations/complaint-officers-were-discriminatory-and-excessive-their-restraint-man-lancashire
# https://policeconduct.gov.uk/recommendations/restraint-man-after-roof-fall-west-midlands-police-september-2018
# https://policeconduct.gov.uk/recommendations/man-sustained-serious-injury-following-his-arrest-merseyside-police-february-2019
# https://policeconduct.gov.uk/recommendations/use-force-during-arrest-west-yorkshire-police-april-2019
# https://policeconduct.gov.uk/recommendations/pursuit-vehicle-west-midlands-police-october-2019
# https://policeconduct.gov.uk/recommendations/use-force-during-man%E2%80%99s-arrest-and-detention-and-subsequent-treatment-metropolitan
# https://policeconduct.gov.uk/recommendations/collision-vehicle-being-pursued-west-midlands-police-31-august-2019
# https://policeconduct.gov.uk/recommendations/fatal-road-collision-after-pursuit-staffordshire-police-april-2018
# https://policeconduct.gov.uk/recommendations/use-force-woman-thames-valley-police-8-march-2019
# https://policeconduct.gov.uk/recommendations/use-force-man-when-being-arrested-metropolitan-police-service-february-2019
# https://policeconduct.gov.uk/recommendations/national-recommendation-national-police-chiefs-council-november-2020-0
# https://policeconduct.gov.uk/recommendations/recommendation-metropolitan-police-service-november-2020-0
# https://policeconduct.gov.uk/recommendations/recommendations-metropolitan-police-service-december-2020
# https://policeconduct.gov.uk/recommendations/recommendation-metropolitan-police-service-october-2020
# https://policeconduct.gov.uk/recommendations/recommendation-metropolitan-police-service-november-2020
# https://policeconduct.gov.uk/recommendations/self-inflicted-wound-custody-west-midlands-police-april-2019
# https://policeconduct.gov.uk/recommendations/death-hospital-after-arrest-cleveland-police-march-2019
# https://policeconduct.gov.uk/recommendations/police-response-concerns-welfare-man-cambridgeshire-constabulary-april-2019
# https://policeconduct.gov.uk/recommendations/response-concern-welfare-calls-cambridgeshire-constabulary-february-and-march-2018
# https://policeconduct.gov.uk/recommendations/recommendation-west-midlands-police-august-2020
# https://policeconduct.gov.uk/recommendations/recommendation-derbyshire-constabulary-november-2020
# https://policeconduct.gov.uk/recommendations/recommendation-devon-and-cornwall-constabulary-august-2020
# https://policeconduct.gov.uk/recommendations/call-handling-and-deployment-officers-essex-police-october-2019
# https://policeconduct.gov.uk/recommendations/allegations-inappropriate-contact-vulnerable-victim-crime-hampshire-constabulary
# https://policeconduct.gov.uk/recommendations/national-recommendation-national-police-chiefs-council-november-2020
# https://policeconduct.gov.uk/recommendations/recommendation-hampshire-constabulary-november-2020
# https://policeconduct.gov.uk/recommendations/contact-woman-prior-her-death-gloucestershire-constabulary-march-2019
# https://policeconduct.gov.uk/recommendations/response-report-missing-vulnerable-teenager-west-midlands-april-2018
# https://policeconduct.gov.uk/recommendations/national-recommendations-national-police-chiefs-council-september-2020
# https://policeconduct.gov.uk/recommendations/recommendation-cleveland-police-october-2020
# https://policeconduct.gov.uk/recommendations/response-missing-person-report-and-investigation-death-essex-police-march-2018
# https://policeconduct.gov.uk/recommendations/sexual-assault-allegations-custody-facility-staffordshire-police-june-2016
# https://policeconduct.gov.uk/recommendations/alleged-sexual-relationship-victim-domestic-abuse-metropolitan-police-april-2019
# https://policeconduct.gov.uk/recommendations/man-injured-during-pursuit-south-yorkshire-police-march-2019
# https://policeconduct.gov.uk/recommendations/response-report-domestic-abuse-west-yorkshire-police-september-2019
# https://policeconduct.gov.uk/recommendations/police-interaction-man-prior-his-death-staffordshire-police-july-2019
# https://policeconduct.gov.uk/recommendations/allegations-made-former-officer-operation-talon-cleveland-police-december-2017
# https://policeconduct.gov.uk/recommendations/recommendation-stop-and-search-deptford-metropolitan-police-february-2018
# https://policeconduct.gov.uk/recommendations/recommendation-stop-and-search-harlesden-metropolitan-police-october-2018
# https://policeconduct.gov.uk/recommendations/use-taser-west-midlands-police-september-2018
# https://policeconduct.gov.uk/recommendations/police-contact-man-prior-assault-his-ex-partner-cambridgeshire-constabulary-august
# https://policeconduct.gov.uk/recommendations/recommendation-stop-and-search-euston-metropolitan-police-service-november-2019
# https://policeconduct.gov.uk/recommendations/recommendation-stop-and-search-romford-metropolitan-police-april-2019
# https://policeconduct.gov.uk/recommendations/welfare-vulnerable-person-metropolitan-police-service-july-2019
# https://policeconduct.gov.uk/recommendations/recommendation-greater-manchester-police-september-2020
# https://policeconduct.gov.uk/recommendations/recommendations-metropolitan-police-service-june-2020
# https://policeconduct.gov.uk/recommendations/recommendations-cleveland-police-april-2020
# https://policeconduct.gov.uk/recommendations/recommendation-essex-police-september-2020
# https://policeconduct.gov.uk/recommendations/recommendations-sussex-police-march-2020
# https://policeconduct.gov.uk/recommendations/use-force-fifteen-year-old-boy-bedfordshire-police-december-2017
# https://policeconduct.gov.uk/recommendations/use-force-custody-west-midlands-police-november-2018
# https://policeconduct.gov.uk/recommendations/death-man-after-disturbance-kent-police-june-2018
# https://policeconduct.gov.uk/recommendations/inappropriate-relationship-vulnerable-person-%E2%80%93-hertfordshire-constabulary-october
# https://policeconduct.gov.uk/recommendations/injuries-received-detainee-%E2%80%93-lancashire-police-january-2020
# https://policeconduct.gov.uk/recommendations/fatal-collision-after-pursuit-west-yorkshire-police-february-2018
# https://policeconduct.gov.uk/recommendations/recommendation-stop-and-search-brent-metropolitan-police-june-2018
# https://policeconduct.gov.uk/recommendations/boy-bicycle-injured-car-driver-being-pursued-officers-west-yorkshire-police-june
# https://policeconduct.gov.uk/recommendations/recommendation-wiltshire-constabulary-july-2020
# https://policeconduct.gov.uk/recommendations/road-traffic-collision-after-pursuit-%E2%80%93-metropolitan-police-august-2018
# https://policeconduct.gov.uk/recommendations/response-emergency-call-%E2%80%93-essex-police-april-2019
# https://policeconduct.gov.uk/recommendations/response-concern-welfare-%E2%80%93-northumbria-police-october-2019
# https://policeconduct.gov.uk/recommendations/use-force-and-care-during-custody-humberside-police-august-2019
# https://policeconduct.gov.uk/recommendations/police-response-concern-welfare-warwickshire-police-october-2018
# https://policeconduct.gov.uk/recommendations/use-taser-%E2%80%93-metropolitan-police-service-january-2020
# https://policeconduct.gov.uk/recommendations/recommendation-sussex-police-september-2020
# https://policeconduct.gov.uk/recommendations/recommendations-west-yorkshire-police-june-2020
# https://policeconduct.gov.uk/recommendations/failure-duties-%E2%80%93-metropolitan-police-service-july-2019
# https://policeconduct.gov.uk/recommendations/complaint-regarding-inappropriate-contact-pcso-cleveland-police-may-2019
# https://policeconduct.gov.uk/recommendations/recommendations-metropolitan-police-service-november-2018
# https://policeconduct.gov.uk/recommendations/police-pursuit-vehicle-driving-speed-%E2%80%93-kent-police-september-2018
# https://policeconduct.gov.uk/recommendations/response-concern-welfare-avon-and-somerset-police-september-2019
# https://policeconduct.gov.uk/recommendations/recommendations-west-midlands-police-july-2020
# https://policeconduct.gov.uk/recommendations/recommendation-thames-valley-police-june-2020
# https://policeconduct.gov.uk/recommendations/national-recommendations-and-recommendations-made-metropolitan-police-service-and
# https://policeconduct.gov.uk/recommendations/recommendation-essex-police-may-2020
# https://policeconduct.gov.uk/recommendations/recommendations-surrey-police-april-2020
# https://policeconduct.gov.uk/recommendations/recommendation-west-mercia-police-march-2020
# https://policeconduct.gov.uk/recommendations/death-man-following-custody-%E2%80%93-warwickshire-police-october-2018
# https://policeconduct.gov.uk/recommendations/recommendation-metropolitan-police-service-april-2020
# https://policeconduct.gov.uk/recommendations/recommendation-metropolitan-police-service-february-2020
# https://policeconduct.gov.uk/recommendations/man-injured-while-being-transported-court-dyfed-powys-police-april-2019
# https://policeconduct.gov.uk/recommendations/police-response-report-man-firearm-humberside-police-december-2019
# https://policeconduct.gov.uk/recommendations/response-request-domestic-violence-disclosure-check-wiltshire-police-april-2019
# https://policeconduct.gov.uk/recommendations/complaints-regarding-police-response-reports-harassment-west-yorkshire-police
# https://policeconduct.gov.uk/recommendations/fatal-collision-following-pursuit-lancashire-constabulary-september-2018
# https://policeconduct.gov.uk/recommendations/police-response-missing-person-report-west-yorkshire-police-may-2018
# https://policeconduct.gov.uk/recommendations/police-contact-woman-her-death-south-yorkshire-police-june-2019
# https://policeconduct.gov.uk/recommendations/complaints-regarding-arrest-merseyside-police-april-2018
# https://policeconduct.gov.uk/recommendations/pedestrian-injured-collision-following-pursuit-metropolitan-police-service-august
# https://policeconduct.gov.uk/recommendations/non-fatal-police-shooting-metropolitan-police-service-march-2018
# https://policeconduct.gov.uk/recommendations/collision-following-pursuit-thames-valley-police-may-2019
# https://policeconduct.gov.uk/recommendations/use-taser-north-yorkshire-police-april-2019
# https://policeconduct.gov.uk/recommendations/motorcyclist-injured-collision-following-pursuit-south-yorkshire-police-april-2019
# https://policeconduct.gov.uk/recommendations/collision-following-pursuit-west-midlands-police-june-2019
# https://policeconduct.gov.uk/recommendations/fatal-collision-hampshire-constabulary-july-2019
# https://policeconduct.gov.uk/recommendations/non-fatal-police-shooting-dorset-police-august-2018
# https://policeconduct.gov.uk/recommendations/collision-following-pursuit-suffolk-constabulary-october-2018
# https://policeconduct.gov.uk/recommendations/police-response-report-assault-west-yorkshire-police-february-2019
# https://policeconduct.gov.uk/recommendations/police-response-and-actions-following-missing-person-report-cumbria-constabulary
# https://policeconduct.gov.uk/recommendations/man-dies-following-contact-police-dorset-police-april-2017
# https://policeconduct.gov.uk/recommendations/fatal-road-traffic-collision-police-car-warwickshire-police-january-2019
# https://policeconduct.gov.uk/recommendations/man-found-dead-after-being-reported-missing-thames-valley-police-april-2018
# https://policeconduct.gov.uk/recommendations/recommendation-west-yorkshire-police-february-2020
# https://policeconduct.gov.uk/recommendations/man-found-dead-after-concern-welfare-report-west-midlands-police-june-2019
# https://policeconduct.gov.uk/recommendations/double-fatal-collision-between-police-motorbike-and-car-thames-valley-police-and
# https://policeconduct.gov.uk/recommendations/complaint-regarding-use-force-and-discriminatory-language-west-yorkshire-police
# https://policeconduct.gov.uk/recommendations/man-injured-during-restraint-metropolitan-police-service-september-2018
# https://policeconduct.gov.uk/recommendations/road-traffic-collision-following-pursuit-avon-and-somerset-constabulary-february
# https://policeconduct.gov.uk/recommendations/allegations-use-excessive-force-and-inappropriate-language-west-midlands-police
# https://policeconduct.gov.uk/recommendations/woman-found-dead-following-concern-welfare-report-thames-valley-police-august-2017
# https://policeconduct.gov.uk/recommendations/man-dies-after-being-restrained-and-tasered-devon-and-cornwall-police-may-2017
# https://policeconduct.gov.uk/recommendations/use-force-during-arrest-and-detention-west-midlands-police-august-2018
# https://policeconduct.gov.uk/recommendations/member-public-injured-collision-during-pursuit-south-yorkshire-police-june-2019
# https://policeconduct.gov.uk/recommendations/stop-and-search-bedfordshire-police-october-2018
# https://policeconduct.gov.uk/recommendations/pursuit-and-road-traffic-collision-metropolitan-police-service-february-2018
# https://policeconduct.gov.uk/recommendations/fatal-road-traffic-collision-south-wales-police-august-2018
# https://policeconduct.gov.uk/recommendations/man-injured-following-pursuit-cambridgeshire-constabulary-november-2018
# https://policeconduct.gov.uk/recommendations/allegations-discrimination-and-computer-misuse-and-how-these-were-handled
# https://policeconduct.gov.uk/recommendations/conduct-officer-involved-vehicle-and-pedestrian-collisions-cambridgeshire
# https://policeconduct.gov.uk/recommendations/complaint-regarding-police-response-call-assistance-and-death-devon-and-cornwall
# https://policeconduct.gov.uk/recommendations/death-following-contact-police-south-wales-police-december-2018
# https://policeconduct.gov.uk/recommendations/man-injured-during-restraint-norfolk-constabulary-april-2019
# https://policeconduct.gov.uk/recommendations/man-found-dead-after-concerns-his-welfare-reported-west-midlands-police-november
# https://policeconduct.gov.uk/recommendations/use-force-metropolitan-police-service-may-2019
# https://policeconduct.gov.uk/recommendations/man-takes-his-own-life-after-being-detained-police-nottinghamshire-police-april-2018
# https://policeconduct.gov.uk/recommendations/man-dies-following-contact-police-north-wales-police-february-2017
# https://policeconduct.gov.uk/recommendations/contact-between-man-and-police-he-found-dead-west-midlands-police-september-2018
# https://policeconduct.gov.uk/recommendations/man-fatally-injured-after-collision-police-car-merseyside-police-december-2018
# https://policeconduct.gov.uk/recommendations/man-dies-while-police-custody-metropolitan-police-service-september-2018
# https://policeconduct.gov.uk/recommendations/officers%E2%80%99-conduct-when-responding-request-assistance-essex-police-january-2019
# https://policeconduct.gov.uk/recommendations/police-officer%E2%80%99s-actions-and-contact-vulnerable-members-public-they-met-while-duty
# https://policeconduct.gov.uk/recommendations/man-becomes-unwell-custody-greater-manchester-police-march-2019
# https://policeconduct.gov.uk/recommendations/response-domestic-incident-south-wales-police-february-2019
# https://policeconduct.gov.uk/recommendations/use-force-during-arrest-metropolitan-police-service-december-2018
# https://policeconduct.gov.uk/recommendations/man-found-dead-after-being-reported-missing-devon-and-cornwall-police-april-2018
# https://policeconduct.gov.uk/recommendations/response-missing-person%E2%80%99s-report-nottinghamshire-police-december-2018
# https://policeconduct.gov.uk/recommendations/contact-between-man-and-police-he-died-dorset-police-january-2019
# https://policeconduct.gov.uk/recommendations/man-found-dead-after-being-reported-missing-south-yorkshire-police-january-2019
# https://policeconduct.gov.uk/recommendations/non-fatal-police-shooting-west-mercia-police-november-2018
# https://policeconduct.gov.uk/recommendations/man-found-dead-after-contact-police-norfolk-constabulary-july-2018
# https://policeconduct.gov.uk/recommendations/injuries-sustained-following-use-tactical-vehicle-contact-during-police-pursuit
# https://policeconduct.gov.uk/recommendations/complaint-regarding-use-taser-west-midlands-police-february-2018
# https://policeconduct.gov.uk/recommendations/police-contact-man-and-woman-he-killed-her-greater-manchester-police-november-2016
# https://policeconduct.gov.uk/recommendations/national-recommendations-and-recommendations-made-metropolitan-police-service
# https://policeconduct.gov.uk/recommendations/conduct-officers-during-arrest-dorset-police-august-2018
# https://policeconduct.gov.uk/recommendations/woman-found-dead-after-being-reported-missing-metropolitan-police-service-september
# https://policeconduct.gov.uk/recommendations/investigation-conduct-police-officers-and-staff-towards-man-custody-metropolitan
# https://policeconduct.gov.uk/recommendations/man-found-dead-after-requesting-police-assistance-devon-and-cornwall-police
# https://policeconduct.gov.uk/recommendations/complaint-regarding-conduct-officer-sussex-police-february-2019
# https://policeconduct.gov.uk/recommendations/officers%E2%80%99-actions-when-finding-man-ligature-around-his-neck-essex-police-december
# https://policeconduct.gov.uk/recommendations/man-reported-missing-later-found-dead-humberside-police-and-lincolnshire-police
# https://policeconduct.gov.uk/recommendations/national-recommendation-college-policing-december-2019
# https://policeconduct.gov.uk/recommendations/complaint-regarding-handling-investigation-including-threats-life-metropolitan
# https://policeconduct.gov.uk/recommendations/removal-and-disposal-sensitive-information-cleveland-police-june-2018
# https://policeconduct.gov.uk/recommendations/recommendation-merseyside-police-november-2019
# https://policeconduct.gov.uk/recommendations/man-becomes-unwell-custody-kent-police-january-2019
# https://policeconduct.gov.uk/recommendations/investigation-use-force-metropolitan-police-service-february-2019
# https://policeconduct.gov.uk/recommendations/pedestrian-injured-after-being-struck-police-car-west-yorkshire-police-november-2018
# https://policeconduct.gov.uk/recommendations/officer%E2%80%99s-actions-and-decision-criminal-investigation-west-mercia-police-july-2018
# https://policeconduct.gov.uk/recommendations/man-dies-after-becoming-unwell-custody-essex-police-november-2017
# https://policeconduct.gov.uk/recommendations/woman-injured-when-taken-ground-metropolitan-police-service-october-2018
# https://policeconduct.gov.uk/recommendations/complaint-inappropriate-behaviour-officer-metropolitan-police-service-july-2018
# https://policeconduct.gov.uk/recommendations/collision-following-pursuit-nottinghamshire-police-november-2018
# https://policeconduct.gov.uk/recommendations/fatal-collision-during-police-pursuit-northamptonshire-police-april-2019
# https://policeconduct.gov.uk/recommendations/man-becomes-unwell-and-dies-after-being-arrested-north-wales-police-february-2019
# https://policeconduct.gov.uk/recommendations/man-found-dead-after-safeguarding-issues-raised-greater-manchester-police-june-2018
# https://policeconduct.gov.uk/recommendations/road-traffic-accident-following-pursuit-and-complaint-about-excessive-force-and
# https://policeconduct.gov.uk/recommendations/man-seriously-injured-after-reporting-he-had-removed-his-electronic-tag-metropolitan
# https://policeconduct.gov.uk/recommendations/recommendations-sussex-police-november-2019
# https://policeconduct.gov.uk/recommendations/collision-between-police-vehicle-and-pedestrian-sussex-police-september-2017
# https://policeconduct.gov.uk/recommendations/pedestrian-injured-after-being-struck-car-pursued-police-metropolitan-police-service
# https://policeconduct.gov.uk/recommendations/complaint-regarding-excessive-use-force-cambridgeshire-constabulary-january-2019
# https://policeconduct.gov.uk/recommendations/man-found-dead-after-being-released-custody-avon-and-somerset-constabulary-may-2018
# https://policeconduct.gov.uk/recommendations/woman-becomes-unwell-custody-south-wales-police-january-2019
# https://policeconduct.gov.uk/recommendations/contact-police-prior-man%E2%80%99s-death-suffolk-constabulary-october-2018
# https://policeconduct.gov.uk/recommendations/multiple-misconduct-allegations-metropolitan-police-service-january-2016
# https://policeconduct.gov.uk/recommendations/allegations-breach-confidentiality-theft-and-perverting-course-justice-humberside
# https://policeconduct.gov.uk/recommendations/moped-driver-injured-after-contact-police-vehicle-metropolitan-police-service
# https://policeconduct.gov.uk/recommendations/woman-and-man-found-dead-after-contact-police-northumbria-police-september-2018
# https://policeconduct.gov.uk/recommendations/man-found-dead-after-being-reported-missing-metropolitan-police-service-june-2018
# https://policeconduct.gov.uk/recommendations/man-dies-following-his-release-custody-norfolk-constabulary-july-2018
# https://policeconduct.gov.uk/recommendations/man-dies-collision-after-being-reported-police-%E2%80%98-trouble%E2%80%99-road-thames-valley-police
# https://policeconduct.gov.uk/recommendations/collision-following-pursuit-bedfordshire-police-november-2018
# https://policeconduct.gov.uk/recommendations/police-interaction-man-and-use-force-metropolitan-police-service-may-2019
# https://policeconduct.gov.uk/recommendations/fatal-collision-following-pursuit-northumbria-police-september-2018
# https://policeconduct.gov.uk/recommendations/woman-found-dead-after-concerns-her-welfare-reported-police-sussex-police-july-2018
# https://policeconduct.gov.uk/recommendations/recommendations-essex-police-september-2019
# https://policeconduct.gov.uk/recommendations/allegations-excessive-use-force-and-use-insultingabusive-language-northamptonshire
# https://policeconduct.gov.uk/recommendations/fatal-crash-following-pursuit-merseyside-police-october-2017
# https://policeconduct.gov.uk/recommendations/man-becomes-unwell-custody-metropolitan-police-service-january-2019
# https://policeconduct.gov.uk/recommendations/man-injured-during-restraint-northumbria-police-january-2019
# https://policeconduct.gov.uk/recommendations/man-dies-after-becoming-unwell-custody-suffolk-constabulary-december-2015
# https://policeconduct.gov.uk/recommendations/collision-following-pursuit-metropolitan-police-service-november-2017
# https://policeconduct.gov.uk/recommendations/woman-reported-missing-found-dead-metropolitan-police-service-august-2018
# https://policeconduct.gov.uk/recommendations/man%E2%80%99s-contact-police-his-death-essex-police-october-2017
# https://policeconduct.gov.uk/recommendations/response-concern-welfare-calls-gwent-police-january-2019
# https://policeconduct.gov.uk/recommendations/man-dies-while-custody-kent-police-october-2017
# https://policeconduct.gov.uk/recommendations/fatal-collision-following-pursuit-metropolitan-police-service-february-2019
# https://policeconduct.gov.uk/recommendations/complaints-regarding-use-force-west-midlands-police-june-2018
# https://policeconduct.gov.uk/recommendations/man-dies-after-becoming-unwell-custody-metropolitan-police-service-march-2018
# https://policeconduct.gov.uk/recommendations/response-missing-person-report-metropolitan-police-service-september-2018
# https://policeconduct.gov.uk/recommendations/allegations-racial-discrimination-bedfordshire-police-july-2014
# https://policeconduct.gov.uk/recommendations/response-man-reporting-committing-assault-lancashire-constabulary-august-2018
# https://policeconduct.gov.uk/recommendations/fatal-collision-following-pursuit-greater-manchester-police-july-2018
# https://policeconduct.gov.uk/recommendations/police-response-report-person-bridge-north-wales-police-march-2019
# https://policeconduct.gov.uk/recommendations/fatal-collision-following-pursuit-west-mercia-police-december-2016
# https://policeconduct.gov.uk/recommendations/woman-becomes-unconscious-while-custody-durham-constabulary-february-2019
# https://policeconduct.gov.uk/recommendations/pedestrians-injured-collision-following-pursuit-kent-police-september-2018
# https://policeconduct.gov.uk/recommendations/officer-actions-following-road-traffic-incident-essex-police-november-2018
# https://policeconduct.gov.uk/recommendations/police-contact-woman-her-death-norfolk-constabulary-february-2019
# https://policeconduct.gov.uk/recommendations/man-sustains-injuries-while-custody-thames-valley-police-january-2019
# https://policeconduct.gov.uk/recommendations/investigation-relationship-between-officer-and-member-public-essex-police-october
# https://policeconduct.gov.uk/recommendations/collision-between-police-car-and-pedestrian-hertfordshire-constabulary-september
# https://policeconduct.gov.uk/recommendations/conduct-custody-sergeant-during-search-west-mercia-police-december-2018
# https://policeconduct.gov.uk/recommendations/police-actions-locate-man-later-found-dead-lincolnshire-police-january-2018
# https://policeconduct.gov.uk/recommendations/complaints-regarding-arrest-and-detention-thames-valley-police-august-2017
# https://policeconduct.gov.uk/recommendations/police-actions-following-report-rape-northamptonshire-police-march-2018
# https://policeconduct.gov.uk/recommendations/actions-following-missing-persons-report-essex-police-may-2018
# https://policeconduct.gov.uk/recommendations/passenger-sustains-injuries-crash-following-pursuit-essex-police-november-2018
# https://policeconduct.gov.uk/recommendations/police-actions-regarding-concerns-man%E2%80%99s-welfare-metropolitan-police-service-august
# https://policeconduct.gov.uk/recommendations/man-sustains-injury-during-arrest-hertfordshire-constabulary-june-2018
# https://policeconduct.gov.uk/recommendations/complaint-use-excessive-force-metropolitan-police-service-november-2017
# https://policeconduct.gov.uk/recommendations/man-dies-following-contact-police-staffordshire-police-march-2018
# https://policeconduct.gov.uk/recommendations/pedestrian-injured-collision-during-pursuit-metropolitan-police-service-july-2017
# https://policeconduct.gov.uk/recommendations/man-found-dead-after-concerns-his-welfare-were-reported-sussex-police-june-2018
# https://policeconduct.gov.uk/recommendations/complaint-regarding-use-taser-thames-valley-police-february-2017
# https://policeconduct.gov.uk/recommendations/man-dies-way-custody-thames-valley-police-november-2017
# https://policeconduct.gov.uk/recommendations/police-contact-man-and-woman-he-murdered-her-sussex-police-august-2016
# https://policeconduct.gov.uk/recommendations/complaint-regarding-police-involvement-man-his-death-surrey-police-january-2017
# https://policeconduct.gov.uk/recommendations/pursuit-and-use-force-metropolitan-police-service-may-2018
# https://policeconduct.gov.uk/recommendations/collision-involving-car-followed-police-hampshire-constabulary-september-2018
# https://policeconduct.gov.uk/recommendations/fatal-collision-between-pursued-car-and-pedestrian-leicestershire-police-january
# https://policeconduct.gov.uk/recommendations/man-becomes-unresponsive-while-being-restrained-custody-and-care-man-while-custody
# https://policeconduct.gov.uk/recommendations/complaints-regarding-arrest-alleged-excessive-use-force-and-discrimination-avon-and
# https://policeconduct.gov.uk/recommendations/police-contact-woman-her-murder-north-wales-police-august-2017
# https://policeconduct.gov.uk/recommendations/woman%E2%80%99s-contact-police-her-death-greater-manchester-police-august-2018
# https://policeconduct.gov.uk/recommendations/police-contact-woman-her-death-dorset-police-august-2018
# https://policeconduct.gov.uk/recommendations/police-actions-after-woman-reported-missing-suffolk-constabulary-december-2018
# https://policeconduct.gov.uk/recommendations/man-found-dead-following-contact-police-kent-police-october-2018
# https://policeconduct.gov.uk/recommendations/response-reports-threats-cleveland-police-and-cheshire-constabulary-march-2018
# https://policeconduct.gov.uk/recommendations/alleged-use-racially-discriminatory-language-greater-manchester-police-february-2018
# https://policeconduct.gov.uk/recommendations/pursued-car-collides-pedestrian-bedfordshire-police-march-2018
# https://policeconduct.gov.uk/recommendations/police-response-woman%E2%80%99s-emergency-call-her-death-merseyside-police-november-2018
# https://policeconduct.gov.uk/recommendations/fatal-road-traffic-incident-involving-police-van-south-yorkshire-police-december
# https://policeconduct.gov.uk/recommendations/man%E2%80%99s-contact-police-his-death-west-yorkshire-police-may-2018
# https://policeconduct.gov.uk/recommendations/allegations-assault-and-degrading-treatment-while-custody-west-midlands-police-april
# https://policeconduct.gov.uk/recommendations/allegations-use-offensive-language-hampshire-constabulary-may-2018
# https://policeconduct.gov.uk/recommendations/allegations-inappropriate-relationship-between-officer-and-vulnerable-woman-surrey
# https://policeconduct.gov.uk/recommendations/response-concern-welfare-report-kent-police-july-2018
# https://policeconduct.gov.uk/recommendations/allegations-interference-provision-witness-accounts-hampshire-constabulary-february
# https://policeconduct.gov.uk/recommendations/complaint-regarding-use-force-west-yorkshire-police-february-2019
# https://policeconduct.gov.uk/recommendations/recommendation-college-policing-and-national-police-chiefs-council-august-2019
# https://policeconduct.gov.uk/recommendations/response-calls-assistance-metropolitan-police-service-june-2018
# https://policeconduct.gov.uk/recommendations/collision-involving-police-vehicle-thames-valley-police-january-2018
# https://policeconduct.gov.uk/recommendations/police-contact-woman-she-seriously-injured-greater-manchester-police-september-2016
# https://policeconduct.gov.uk/recommendations/serious-injury-following-collision-metropolitan-police-service-september-2018
# https://policeconduct.gov.uk/recommendations/woman-becomes-unwell-custody-dyfed-powys-police-october-2017
# https://policeconduct.gov.uk/recommendations/collision-following-pursuit-kent-police-november-2018
# https://policeconduct.gov.uk/recommendations/road-traffic-incident-reported-fatal-collision-thames-valley-police-october-2018
# https://policeconduct.gov.uk/recommendations/man-injured-during-arrest-nottinghamshire-police-december-2016
# https://policeconduct.gov.uk/recommendations/complaint-regarding-police-action-following-report-racial-abuse-metropolitan-police
# https://policeconduct.gov.uk/recommendations/use-force-during-detention-greater-manchester-police-november-2015
# https://policeconduct.gov.uk/recommendations/man-dies-following-contact-police-june-2017-metropolitan-police-service
# https://policeconduct.gov.uk/recommendations/response-following-concern-welfare-report-northumbria-police-november-2017
# https://policeconduct.gov.uk/recommendations/woman%E2%80%99s-contact-police-she-died-west-mercia-police-and-staffordshire-police-january
# https://policeconduct.gov.uk/recommendations/response-missing-person%E2%80%99s-report-metropolitan-police-service-august-2018
# https://policeconduct.gov.uk/recommendations/man-sustains-injuries-after-calling-police-greater-manchester-police-october-2016
# https://policeconduct.gov.uk/recommendations/allegations-assault-metropolitan-police-service-may-2017
# https://policeconduct.gov.uk/recommendations/pedestrian-injured-collision-greater-manchester-police-march-2017
# https://policeconduct.gov.uk/recommendations/man-dies-after-being-restrained-metropolitan-police-service-july-2017
# https://policeconduct.gov.uk/recommendations/actions-following-report-possible-criminal-activity-british-transport-police
# https://policeconduct.gov.uk/recommendations/collision-following-pursuit-merseyside-police-february-2018
# https://policeconduct.gov.uk/recommendations/woman-found-dead-after-being-reported-missing-cambridgeshire-constabulary-april-2018
# https://policeconduct.gov.uk/recommendations/contact-police-man-died-west-yorkshire-police-june-2018
# https://policeconduct.gov.uk/recommendations/injuries-received-during-contact-police-west-yorkshire-police-september-2018
# https://policeconduct.gov.uk/recommendations/man-becomes-unwell-custody-northumbria-police-october-2018
# https://policeconduct.gov.uk/recommendations/police-contact-man%E2%80%99s-death-kent-police-june-2018
# https://policeconduct.gov.uk/recommendations/care-man-while-custody-avon-and-somerset-constabulary-may-2018
# https://policeconduct.gov.uk/recommendations/young-man-found-dead-after-being-reported-suicidal-avon-and-somerset-constabulary
# https://policeconduct.gov.uk/recommendations/alleged-excessive-use-force-metropolitan-police-service-august-2018
# https://policeconduct.gov.uk/recommendations/allegation-attempts-pursue-inappropriate-relationships-vulnerable-women-avon-and
# https://policeconduct.gov.uk/recommendations/contact-police-man-dies-wiltshire-police-july-2018
# https://policeconduct.gov.uk/recommendations/man-found-dead-after-being-reported-missing-cambridgeshire-constabulary-may-2018
# https://policeconduct.gov.uk/recommendations/man-becomes-unwell-custody-northumbria-police-may-2018
# https://policeconduct.gov.uk/recommendations/police-contact-man-his-death-staffordshire-police-june-2018
# https://policeconduct.gov.uk/recommendations/complaints-about-detention-devon-and-cornwall-police-august-2017
# https://policeconduct.gov.uk/recommendations/man-self-harms-way-custody-staffordshire-police-august-2018
# https://policeconduct.gov.uk/recommendations/fatal-collision-metropolitan-police-service-july-2017
# https://policeconduct.gov.uk/recommendations/allegations-failure-properly-investigate-allegations-childhood-sexual-abuse-essex
# https://policeconduct.gov.uk/recommendations/woman-becomes-unwell-custody-northumbria-police-february-2018
# https://policeconduct.gov.uk/recommendations/high-risk-missing-man-found-dead-lancashire-constabulary-october-2018
# https://policeconduct.gov.uk/recommendations/man-reported-missing-later-found-dead-west-midlands-police-october-2017
# https://policeconduct.gov.uk/recommendations/allegations-excessive-use-force-during-arrest-and-detention-west-midlands-police
# https://policeconduct.gov.uk/recommendations/allegations-assault-during-custody-merseyside-police-october-2016
# https://policeconduct.gov.uk/recommendations/response-missing-person-report-lancashire-constabulary-november-2017
# https://policeconduct.gov.uk/recommendations/man%E2%80%99s-contact-police-his-death-greater-manchester-police-october-2017
# https://policeconduct.gov.uk/recommendations/complaint-regarding-injury-sustained-during-restraint-metropolitan-police-service
# https://policeconduct.gov.uk/recommendations/road-accident-involving-police-car-and-motorbike-metropolitan-police-service-june
# https://policeconduct.gov.uk/recommendations/collision-following-pursuit-metropolitan-police-service-november-2018
# https://policeconduct.gov.uk/recommendations/complaint-regarding-contact-woman-metropolitan-police-service-january-2017
# https://policeconduct.gov.uk/recommendations/use-force-during-arrest-greater-manchester-police-november-2017
# https://policeconduct.gov.uk/recommendations/actions-response-missing-person-report-greater-manchester-police-june-2018
# https://policeconduct.gov.uk/recommendations/woman%E2%80%99s-contact-police-she-sustained-serious-injuries-greater-manchester-police-june
# https://policeconduct.gov.uk/recommendations/complaint-relating-safeguarding-teenager-metropolitan-police-service-february-2018
# https://policeconduct.gov.uk/recommendations/complaints-regarding-arrest-and-detention-metropolitan-police-service-november-2017
# https://policeconduct.gov.uk/recommendations/response-concern-welfare-reports-lincolnshire-police-february-2017
# https://policeconduct.gov.uk/recommendations/police-contact-man-he-dies-northamptonshire-police-march-2018
# https://policeconduct.gov.uk/recommendations/complaints-regarding-police-actions-and-decisions-woman-found-dead-staffordshire
# https://policeconduct.gov.uk/recommendations/response-missing-person%E2%80%99s-report-metropolitan-police-service-june-2015
# https://policeconduct.gov.uk/recommendations/man-found-dead-after-being-reported-missing-west-midlands-police-february-2018
# https://policeconduct.gov.uk/recommendations/fatal-collision-metropolitan-police-service-december-2015
# https://policeconduct.gov.uk/recommendations/woman-sustains-life-changing-injuries-after-contact-police-avon-and-somerset
# https://policeconduct.gov.uk/recommendations/woman-injured-car-following-pursuit-cambridgeshire-police-july-2018
# https://policeconduct.gov.uk/recommendations/man-found-dead-after-being-reported-missing-greater-manchester-police-january-2018
# https://policeconduct.gov.uk/recommendations/actions-taken-following-missing-person%E2%80%99s-report-essex-police-march-2018
# https://policeconduct.gov.uk/recommendations/response-threats-kills-bedfordshire-police-july-2018
# https://policeconduct.gov.uk/recommendations/use-excessive-force-and-unprofessional-language-during-restraint-greater-manchester
# https://policeconduct.gov.uk/recommendations/investigation-woman%E2%80%99s-contact-police-her-death-metropolitan-police-service-july-2013
# https://policeconduct.gov.uk/recommendations/response-safe-and-well-check-request-west-mercia-police-march-2018
# https://policeconduct.gov.uk/recommendations/man-becomes-unwell-after-arrest-west-yorkshire-police-november-2017
# https://policeconduct.gov.uk/recommendations/response-concern-welfare-call-west-midlands-police-september-2017
# https://policeconduct.gov.uk/recommendations/complaint-inappropriate-relationship-between-officer-and-elderly-woman-derbyshire
# https://policeconduct.gov.uk/recommendations/investigation-conduct-police-inspector-gloucestershire-constabulary-september-2015
# https://policeconduct.gov.uk/recommendations/complaint-regarding-police-actions-west-mercia-police-april-2018
# https://policeconduct.gov.uk/recommendations/response-breach-bail-conditions-metropolitan-police-service-january-2018
# https://policeconduct.gov.uk/recommendations/national-recommendation-national-police-chiefs-council-april-2019
# https://policeconduct.gov.uk/recommendations/response-reports-harassment-sussex-police-february-%E2%80%93-march-2018
# https://policeconduct.gov.uk/recommendations/man-dies-following-contact-police-lincolnshire-police-december-2016
# https://policeconduct.gov.uk/recommendations/road-accident-after-pursuit-greater-manchester-police-june-2018
# https://policeconduct.gov.uk/recommendations/collision-following-pursuit-metropolitan-police-service-august-2018
# https://policeconduct.gov.uk/recommendations/complaint-excessive-force-and-discriminatory-behaviour-metropolitan-police-service
# https://policeconduct.gov.uk/recommendations/man-shot-and-wounded-firearms-officer-west-midlands-police-july-2017
# https://policeconduct.gov.uk/recommendations/man-found-dead-following-report-concern-his-welfare-north-yorkshire-police-april
# https://policeconduct.gov.uk/recommendations/allegations-inappropriate-comments-made-officer-greater-manchester-police-march-2018
# https://policeconduct.gov.uk/recommendations/allegations-discrimination-basis-ethnicity-kent-police-february-2018
# https://policeconduct.gov.uk/recommendations/contact-police-man-died-staffordshire-police-november-2018
# https://policeconduct.gov.uk/recommendations/complaint-about-police-action-following-reports-concern-west-yorkshire-police
# https://policeconduct.gov.uk/recommendations/fatal-collision-hampshire-constabulary-march-2017
# https://policeconduct.gov.uk/recommendations/handling-missing-person%E2%80%99s-investigation-sussex-police-june-2017
# https://policeconduct.gov.uk/recommendations/collision-between-police-car-and-pedestrian-metropolitan-police-service-november
# https://policeconduct.gov.uk/recommendations/man-dies-after-contact-police-thames-valley-police-march-2018
# https://policeconduct.gov.uk/recommendations/man-self-harms-custody-city-london-police-october-2017
# https://policeconduct.gov.uk/recommendations/contact-between-man-and-police-officers-west-midlands-police-august-2017
# https://policeconduct.gov.uk/recommendations/response-concern-welfare-report-greater-manchester-police-july-2018
# https://policeconduct.gov.uk/recommendations/road-traffic-accident-following-pursuit-greater-manchester-police-june-2018
# https://policeconduct.gov.uk/recommendations/complaint-regarding-force-used-during-arrest-nottinghamshire-police-november-2017
# https://policeconduct.gov.uk/recommendations/contact-police-woman-allegedly-assaulted-northamptonshire-police-june-2018
# https://policeconduct.gov.uk/recommendations/collision-following-pursuit-staffordshire-police-october-2018
# https://policeconduct.gov.uk/recommendations/response-concern-welfare-report-greater-manchester-police-february-2018
# https://policeconduct.gov.uk/recommendations/man-dies-custody-hertfordshire-constabulary-september-2017
# https://policeconduct.gov.uk/recommendations/man-self-harms-custody-dyfed-powys-police-june-2017
# https://policeconduct.gov.uk/recommendations/response-missing-person%E2%80%99s-report-warwickshire-police-july-2017
# https://policeconduct.gov.uk/recommendations/police-actions-during-murder-investigation-1976-north-wales-police-august-2016
# https://policeconduct.gov.uk/recommendations/actions-following-reports-threats-kill-dorset-police-may-2015
# https://policeconduct.gov.uk/recommendations/response-domestic-violence-incidents-kent-police-february%E2%80%93march-2018
# https://policeconduct.gov.uk/recommendations/man-dies-following-contact-police-north-yorkshire-police-june-2016
# https://policeconduct.gov.uk/recommendations/contact-police-death-essex-police-march-2018
# https://policeconduct.gov.uk/recommendations/man-dies-following-contact-police-greater-manchester-police-february-2018
# https://policeconduct.gov.uk/recommendations/police-contact-man-his-death-metropolitan-police-service-april-2018
# https://policeconduct.gov.uk/recommendations/collision-during-pursuit-south-yorkshire-police-december-2017
# https://policeconduct.gov.uk/recommendations/man-dies-following-contact-police-west-midlands-police-september-2017
# https://policeconduct.gov.uk/recommendations/collision-following-pursuit-metropolitan-police-service-january-2018
# https://policeconduct.gov.uk/recommendations/man-collapses-custody-metropolitan-police-service-june-2017
# https://policeconduct.gov.uk/recommendations/police-contact-two-people-moped-collision-greater-manchester-police-june-2018
# https://policeconduct.gov.uk/recommendations/man-injured-during-restraint-and-arrest-thames-valley-police-march-2018
# https://policeconduct.gov.uk/recommendations/response-concern-welfare-call-south-yorkshire-police-june-2018
# https://policeconduct.gov.uk/recommendations/man-self-harms-during-contact-police-cleveland-police-august-2018
# https://policeconduct.gov.uk/recommendations/collision-involving-police-vehicle-avon-and-somerset-constabulary-may-2018
# https://policeconduct.gov.uk/recommendations/man-injured-during-arrest-west-midlands-police-april-2018
# ...
# https://policeconduct.gov.uk/recommendations/response-concern-welfare-calls-lancashire-constabulary-march-2016
# https://policeconduct.gov.uk/recommendations/recommendation-essex-police-august-2017
# https://policeconduct.gov.uk/recommendations/man-became-unwell-while-custody-gwent-police-october-2016
# https://policeconduct.gov.uk/recommendations/investigation-police-actions-including-monitoring-man-bail-norfolk-and-suffolk
# https://policeconduct.gov.uk/recommendations/man-shot-and-injured-police-metropolitan-police-service-october-2015
# https://policeconduct.gov.uk/recommendations/man-injured-while-custody-south-wales-police-december-2015
# https://policeconduct.gov.uk/recommendations/alleged-use-excessive-force-merseyside-police-march-2016
# https://policeconduct.gov.uk/recommendations/investigation-statements-drafted-and-provided-cps-south-yorkshire-police-november
# https://policeconduct.gov.uk/recommendations/complaint-about-excessive-use-force-and-strip-search-thames-valley-police-september
# https://policeconduct.gov.uk/recommendations/excessive-use-force-thames-valley-police-august-2016
# https://policeconduct.gov.uk/recommendations/alleged-failings-regarding-welfare-vulnerable-persons-norfolk-constabulary-january
# https://policeconduct.gov.uk/recommendations/man-self-harms-while-custody-hertfordshire-police-may-2016
# https://policeconduct.gov.uk/recommendations/allegations-discriminatory-language-and-behaviour-south-yorkshire-police-october
# https://policeconduct.gov.uk/recommendations/allegations-inappropriate-relationship-between-officer-and-suspect-hampshire
# https://policeconduct.gov.uk/recommendations/response-police-officer-report-assault-northamptonshire-police-august-2016
# https://policeconduct.gov.uk/recommendations/complaint-against-use-force-west-midlands-police-november-2015
# https://policeconduct.gov.uk/recommendations/investigation-contact-between-police-and-man-prior-his-death-norfolk-constabulary
# https://policeconduct.gov.uk/recommendations/contact-man-prior-his-death-hertfordshire-constabulary-september-2016
# https://policeconduct.gov.uk/recommendations/recommendations-surrey-police-september-2015
# https://policeconduct.gov.uk/recommendations/investigation-missing-person-cambridgeshire-constabulary-and-metropolitan-police
# https://policeconduct.gov.uk/recommendations/handling-report-missing-person-staffordshire-police-september-2016
# https://policeconduct.gov.uk/recommendations/police-response-incident-metropolitan-police-service-8%E2%80%939-december-2016
# https://policeconduct.gov.uk/recommendations/use-taser-durham-constabulary-february-2017
# https://policeconduct.gov.uk/recommendations/man-injured-during-arrest-greater-manchester-police-september-2015
# https://policeconduct.gov.uk/recommendations/response-domestic-violence-incident-surrey-police-august-2016
# https://policeconduct.gov.uk/recommendations/allegations-excessive-force-west-mercia-police-november-2016
# https://policeconduct.gov.uk/recommendations/alleged-use-excessive-force-and-inappropriate-language-west-midlands-police-june
# https://policeconduct.gov.uk/recommendations/man-sustains-injuries-during-arrest-cheshire-constabulary-may-2017
# https://policeconduct.gov.uk/recommendations/national-recommendation-national-police-chiefs-council-september-2017
# https://policeconduct.gov.uk/recommendations/national-recommendations-national-police-chiefs-council-august-2017
# https://policeconduct.gov.uk/recommendations/investigation-police-contact-man-prior-his-death-humberside-police-september-2015
# https://policeconduct.gov.uk/recommendations/alleged-use-force-during-arrest-west-midlands-police-march-2016
# https://policeconduct.gov.uk/recommendations/alleged-assault-and-use-abusive-language-during-arrest-essex-police-may-2016
# https://policeconduct.gov.uk/recommendations/investigation-handling-allegations-rape-south-yorkshire-police-may-2016
# https://policeconduct.gov.uk/recommendations/response-missing-person-report-nottinghamshire-police-january-2017
# https://policeconduct.gov.uk/recommendations/man-injured-after-being-tasered-north-wales-police-july-2016
# https://policeconduct.gov.uk/recommendations/incident-during-custody-leicestershire-police-april-2016
# https://policeconduct.gov.uk/recommendations/national-recommendations-national-police-chiefs-council-october-2017
# https://policeconduct.gov.uk/recommendations/handling-rape-investigation-greater-manchester-police-may%E2%80%93november-2015
# https://policeconduct.gov.uk/recommendations/man-injured-during-pursuit-avon-and-somerset-constabulary-april-2017
# https://policeconduct.gov.uk/recommendations/woman-injured-while-custody-avon-and-somerset-constabulary-december-2016
# https://policeconduct.gov.uk/recommendations/investigation-police-contact-man-hampshire-constabulary-october-2016
# https://policeconduct.gov.uk/recommendations/alleged-use-excessive-force-metropolitan-police-service-march-2017
# https://policeconduct.gov.uk/recommendations/motorcyclist-involved-collision-after-pursuit-essex-police-august-2016
# https://policeconduct.gov.uk/recommendations/responses-calls-reporting-concerns-neighbour-north-yorkshire-police-october-2016
# https://policeconduct.gov.uk/recommendations/response-999-call-devon-and-cornwall-police-october-2016
# https://policeconduct.gov.uk/recommendations/allegations-use-excessive-force-hampshire-constabulary-july-2016
# https://policeconduct.gov.uk/recommendations/investigation-handling-domestic-violence-case-northamptonshire-police-march-2017
# https://policeconduct.gov.uk/recommendations/woman-self-harms-while-custody-gwent-police-november-2015
# https://policeconduct.gov.uk/recommendations/man-raises-complaints-after-being-bitten-police-dog-greater-manchester-police-july
# https://policeconduct.gov.uk/recommendations/contact-between-police-and-man-he-stabbed-two-people-durham-constabulary-july-2016
# https://policeconduct.gov.uk/recommendations/injuries-following-pursuit-avon-and-somerset-police-march-2017
# https://policeconduct.gov.uk/recommendations/alleged-use-excessive-force-cheshire-constabulary-december-2016
# https://policeconduct.gov.uk/recommendations/man-killed-road-accident-northumbria-police-september-2015
# https://policeconduct.gov.uk/recommendations/woman-found-dead-after-being-detained-west-yorkshire-police-may%E2%80%93june-2017
# https://policeconduct.gov.uk/recommendations/alleged-use-excessive-force-bedfordshire-police-october-2015
# https://policeconduct.gov.uk/recommendations/response-report-concerns-welfare-kent-police-december-2016
# https://policeconduct.gov.uk/recommendations/investigation-actions-senior-investigating-officer-following-allegations-sexual
# https://policeconduct.gov.uk/recommendations/alleged-use-excessive-force-essex-police-december-2016
# https://policeconduct.gov.uk/recommendations/investigation-collision-which-led-death-man-thames-valley-police-july-2016
# https://policeconduct.gov.uk/recommendations/response-999-calls-hertfordshire-constabulary-september-2015
# https://policeconduct.gov.uk/recommendations/death-passenger-car-crash-following-brief-pursuit-bedfordshire-police-august-2016
# https://policeconduct.gov.uk/recommendations/police-action-during-search-staffordshire-police-june-2017
# https://policeconduct.gov.uk/recommendations/response-concern-welfare-report-metropolitan-police-service-november-2016
# https://policeconduct.gov.uk/recommendations/recommendations-metropolitan-police-service-august-2017
# https://policeconduct.gov.uk/recommendations/response-concern-safety-report-merseyside-police-june-2017
# https://policeconduct.gov.uk/recommendations/car-collides-child-after-being-followed-police-vehicle-british-transport-police
# https://policeconduct.gov.uk/recommendations/investigation-near-miss-custody-north-wales-police-may-2016
# https://policeconduct.gov.uk/recommendations/fatal-road-collision-following-pursuit-west-midlands-police-march-2017
# https://policeconduct.gov.uk/recommendations/handling-reports-sexual-assault-north-yorkshire-police-june-2016
# https://policeconduct.gov.uk/recommendations/handling-reports-concern-welfare-greater-manchester-police-december-2016
# https://policeconduct.gov.uk/recommendations/actions-police-regarding-evidence-seized-mobile-phone-greater-manchester-police-2014
# https://policeconduct.gov.uk/recommendations/man-dies-following-arrest-west-midlands-police-october-2016
# https://policeconduct.gov.uk/recommendations/pedestrian-killed-collision-after-pursuit-south-yorkshire-police-march-2017
# https://policeconduct.gov.uk/recommendations/man-injured-while-being-pursued-greater-manchester-police-november-2015
# https://policeconduct.gov.uk/recommendations/alleged-use-excessive-force-lancashire-constabulary-june-2015
# https://policeconduct.gov.uk/recommendations/recommendations-hampshire-constabulary-october-2017
# https://policeconduct.gov.uk/recommendations/allegations-racial-abuse-and-excessive-use-force-dorset-police-november-2015
# https://policeconduct.gov.uk/recommendations/response-concerns-welfare-south-wales-police-december-2015
# https://policeconduct.gov.uk/recommendations/man-stabs-himself-during-contact-police-nottinghamshire-police-august-2016
# https://policeconduct.gov.uk/recommendations/man-self-harms-while-custody-essex-police-june-2017
# https://policeconduct.gov.uk/recommendations/man-injured-after-contact-police-avon-and-somerset-constabulary-april-2016
# https://policeconduct.gov.uk/recommendations/incidents-involving-man-detention-cheshire-constabulary-november-2016
# https://policeconduct.gov.uk/recommendations/man-bitten-police-dog-when-resisting-arrest-south-yorkshire-police-october-2016
# https://policeconduct.gov.uk/recommendations/woman-injured-while-custody-south-wales-police-august-2016
# https://policeconduct.gov.uk/recommendations/recommendations-metropolitan-police-service-july-2017
# https://policeconduct.gov.uk/recommendations/adverse-incident-during-custody-gwent-police-august-2016
# https://policeconduct.gov.uk/recommendations/handling-domestic-violence-incident-metropolitan-police-service-march-2017
# https://policeconduct.gov.uk/recommendations/police-actions-following-999-call-west-midlands-police-march-2017
# https://policeconduct.gov.uk/recommendations/use-taser-cheshire-constabulary-april-2015
# https://policeconduct.gov.uk/recommendations/police-interaction-vehicle-prior-road-traffic-collision-south-wales-police-october
# https://policeconduct.gov.uk/recommendations/man-dies-following-contact-police-hertfordshire-constabulary-may%E2%80%93june-2017
# https://policeconduct.gov.uk/recommendations/alleged-sexual-assault-during-strip-search-and-actions-custody-sergeant-metropolitan
# https://policeconduct.gov.uk/recommendations/welfare-checks-during-custody-south-wales-police-may-2016
# https://policeconduct.gov.uk/recommendations/investigation-police-contact-man-he-took-his-life-avon-and-somerset-constabulary
# https://policeconduct.gov.uk/recommendations/collision-following-police-pursuit-metropolitan-police-service-april-2016
# https://policeconduct.gov.uk/recommendations/response-concerns-welfare-staffordshire-police-april-2016
# https://policeconduct.gov.uk/recommendations/allegations-discrimination-metropolitan-police-service-december-2015
# https://policeconduct.gov.uk/recommendations/response-concerns-welfare-lancashire-constabulary-october-2016
# https://policeconduct.gov.uk/recommendations/police-response-collision-metropolitan-police-service-june-2016
# https://policeconduct.gov.uk/recommendations/fatal-road-traffic-accident-merseyside-police-march-2017
# https://policeconduct.gov.uk/recommendations/investigation-comments-made-officer-metropolitan-police-service-january-2017
# https://policeconduct.gov.uk/recommendations/fatal-collision-following-pursuit-west-midlands-police-november-2016
# https://policeconduct.gov.uk/recommendations/response-concerns-welfare-south-wales-police-january-2017
# https://policeconduct.gov.uk/recommendations/actions-following-report-concern-nottinghamshire-police-october-2017
# https://policeconduct.gov.uk/recommendations/fatal-road-accident-warwickshire-police-september-2016
# https://policeconduct.gov.uk/recommendations/man-found-dead-after-contact-police-north-wales-police-june-2016
# https://policeconduct.gov.uk/recommendations/alleged-inappropriate-behaviour-officer-greater-manchester-police-october-2016
# https://policeconduct.gov.uk/recommendations/use-taser-hampshire-constabulary-april-2017
# https://policeconduct.gov.uk/recommendations/man-self-harms-and-dies-following-contact-police-northumbria-police-june-2016
# https://policeconduct.gov.uk/recommendations/allegations-assault-and-racist-abuse-greater-manchester-police-october-2015
# https://policeconduct.gov.uk/recommendations/allegations-use-excessive-force-and-other-complaints-nottinghamshire-police-august
# https://policeconduct.gov.uk/recommendations/response-concern-welfare-lancashire-constabulary-april-2016
# https://policeconduct.gov.uk/recommendations/response-number-calls-greater-manchester-police-september-2016
# https://policeconduct.gov.uk/recommendations/collision-following-pursuit-south-yorkshire-police-july-2017
# https://policeconduct.gov.uk/recommendations/response-call-lancashire-constabulary-may-2017
# https://policeconduct.gov.uk/recommendations/response-allegations-woman-had-been-victim-crime-greater-manchester-police-march
# https://policeconduct.gov.uk/recommendations/handling-allegations-domestic-violence-greater-manchester-police-march-2016
# https://policeconduct.gov.uk/recommendations/actions-police-fatal-collision-derbyshire-constabulary-april-2017
# https://policeconduct.gov.uk/recommendations/fatal-collision-essex-police-december-2016
# https://policeconduct.gov.uk/recommendations/response-reports-threats-west-yorkshire-police-november-2016
# https://policeconduct.gov.uk/recommendations/man-self-harms-while-custody-metropolitan-police-service-march-2017
# https://policeconduct.gov.uk/recommendations/handling-investigation-and-allegations-perjury-northumbria-police-september-2014
# https://policeconduct.gov.uk/recommendations/response-reports-assault-cheshire-constabulary-2015-2016
# https://policeconduct.gov.uk/recommendations/collision-between-motorbike-and-police-vehicle-bedfordshire-police-august-2017
# https://policeconduct.gov.uk/recommendations/man-sustains-injuries-following-interaction-police-greater-manchester-police
# https://policeconduct.gov.uk/recommendations/recommendations-devon-and-cornwall-constabulary-november-2017
# https://policeconduct.gov.uk/recommendations/handling-number-domestic-violence-incidents-essex-police-may-2016
# https://policeconduct.gov.uk/recommendations/complaint-excessive-use-force-and-tampering-evidence-cumbria-constabulary-april-2016
# https://policeconduct.gov.uk/recommendations/complaint-use-excessive-force-west-midlands-police-and-warwickshire-police-april
# https://policeconduct.gov.uk/recommendations/investigation-pursuit-and-alleged-excessive-use-force-man-and-his-supervision
# https://policeconduct.gov.uk/recommendations/adverse-incident-newport-central-police-station-gwent-police-may-2017
# https://policeconduct.gov.uk/recommendations/allegations-use-excessive-force-northumbria-police-august-2016
# https://policeconduct.gov.uk/recommendations/man-self-harms-while-custody-gwent-police-april-2016
# https://policeconduct.gov.uk/recommendations/teenager-bitten-police-dog-greater-manchester-police-december-2016
# https://policeconduct.gov.uk/recommendations/response-calls-assistance-durham-constabulary-june-2016
# https://policeconduct.gov.uk/recommendations/response-allegations-domestic-abuse-south-wales-police-july-2015
# https://policeconduct.gov.uk/recommendations/%E2%80%98near-miss%E2%80%99-custody-cheshire-constabulary-january-2017
# https://policeconduct.gov.uk/recommendations/complaint-serious-injury-west-midlands-police-april-2017
# https://policeconduct.gov.uk/recommendations/alleged-use-excessive-force-hampshire-constabulary-june-2017
# https://policeconduct.gov.uk/recommendations/allegations-excessive-use-force-metropolitan-police-service-october-2016

# %% [markdown]
# ## Export results
#
# Now export the results which can be added back in to the original data using `VLOOKUP` in Excel.

# %%
#remove duplicates based on the url column
df = df.drop_duplicates(subset="url")
#And we can export it
df.to_csv("scrapeddata.csv")
